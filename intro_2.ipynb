# %% [markdown]
# Manejo de datos con biblioteca de pandas

# %%
import pandas as pd

# %%
series = pd.Series([5,10,15,20,25])
series
#Similar a "diccionarios"
# Out:
# 0     5
# 1    10
# 2    15
# 3    20
# 4    25
# dtype: int64

# %%
series[3]
# Out:
# 20

# %%
carac = pd.Series(['H','o','l','a'])
carac
# Out:
# 0    H
# 1    o
# 2    l
# 3    a
# dtype: object

# %%
#Data frame -> Conveniente para casos posteriores
lst = ['Hola','mundo',':D']
df = pd.DataFrame(lst)
print(df)
# Out:
#        0
# 0   Hola
# 1  mundo
# 2     :D

# %%
data = {'Nombre': ['Alfonso','Eduardo','Mario','yo again'],
        'Edad':[24,23,21,22], 
        'Pais':['MX','CO','BR','MX']}
df = pd.DataFrame(data)
print(df)
df #La ventaja es que te lo coloca como si fuera una tabla de un archivo de SQL o csv
# Out:
#      Nombre  Edad Pais
# 0   Alfonso    24   MX
# 1   Eduardo    23   CO
# 2     Mario    21   BR
# 3  yo again    22   MX
#      Nombre  Edad Pais
# 0   Alfonso    24   MX
# 1   Eduardo    23   CO
# 2     Mario    21   BR
# 3  yo again    22   MX

# %%
#Imprimir alguna columna como si estuvieramos en SQL
print(df[['Nombre','Pais']])
# Out:
#      Nombre Pais
# 0   Alfonso   MX
# 1   Eduardo   CO
# 2     Mario   BR
# 3  yo again   MX

# %%
#Pestañita -> files
#Uso de archivos csv
data = pd.read_csv('canciones_2018.csv')
#Imprimir los primeros archivos
data.head(10)
# Out:
#                       id  ... time_signature
# 0  6DCZcSspjsKoFjzjrWoCd  ...            4.0
# 1  3ee8Jmje8o58CHK66QrVC  ...            4.0
# 2  0e7ipj03S05BNilyu5bRz  ...            4.0
# 3  3swc6WTsr7rl9DqQKQA55  ...            4.0
# 4  2G7V7zsVDxg1yRsu7Ew9R  ...            4.0
# 5  7dt6x5M1jzdTEt8oCbisT  ...            4.0
# 6  58q2HKrzhC3ozto2nDdN4  ...            4.0
# 7  7ef4DlsgrMEH11cDZd32M  ...            4.0
# 8  76cy1WJvNGJTj78UqeA5z  ...            4.0
# 9  08bNPGLD8AhKpnnERrAc6  ...            4.0
#
# [10 rows x 16 columns]

# %%
artist = data.artists #jala a cada columna como si fuera un atributo del objeto
artist[5] #Lo podemos recorrer como si fuera un arreglo
# Out:
# 'Post Malone'

# %%
info = data.iloc[15]
info #Para revisar que tiene nuestra data
# Out:
# id                     3GCdLUSnKSMJhs4Tj6CV3
# name                All The Stars (with SZA)
# artists                       Kendrick Lamar
# danceability                           0.698
# energy                                 0.633
# key                                        8
# loudness                              -4.946
# mode                                       1
# speechiness                           0.0597
# acousticness                          0.0605
# instrumentalness                    0.000194
# liveness                              0.0926
# valence                                0.552
# tempo                                 96.924
# duration_ms                           232187
# time_signature                             4
# Name: 15, dtype: object

# %%
data.tail()
# Out:
#                        id  ... time_signature
# 95  630sXRhIcfwr2e4RdNtjK  ...            4.0
# 96  2xmrfQpmS2iJExTlklLoA  ...            4.0
# 97  5WvAo7DNuPRmk4APhdPzi  ...            5.0
# 98  1j4kHkkpqZRBwE0A4CN4Y  ...            4.0
# 99  3EPXxR3ImUwfayaurPi3c  ...            4.0
#
# [5 rows x 16 columns]

# %%
data.shape
# Out:
# (100, 16)

# %%
data.columns #Para saber cada columna
# Out:
# Index(['id', 'name', 'artists', 'danceability', 'energy', 'key', 'loudness',
#        'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'duration_ms', 'time_signature'],
#       dtype='object')

# %%
data['tempo'].describe() #Obtendremos toda la información asociada a la columna -> Datos estadíísticos
# Out:
# count    100.000000
# mean     119.904180
# std       28.795984
# min       64.934000
# 25%       95.730750
# 50%      120.116000
# 75%      140.022750
# max      198.075000
# Name: tempo, dtype: float64

# %%
data.sort_index(axis = 0, ascending=False)
# Out:
#                        id  ... time_signature
# 99  3EPXxR3ImUwfayaurPi3c  ...            4.0
# 98  1j4kHkkpqZRBwE0A4CN4Y  ...            4.0
# 97  5WvAo7DNuPRmk4APhdPzi  ...            5.0
# 96  2xmrfQpmS2iJExTlklLoA  ...            4.0
# 95  630sXRhIcfwr2e4RdNtjK  ...            4.0
# ..                    ...  ...            ...
# 4   2G7V7zsVDxg1yRsu7Ew9R  ...            4.0
# 3   3swc6WTsr7rl9DqQKQA55  ...            4.0
# 2   0e7ipj03S05BNilyu5bRz  ...            4.0
# 1   3ee8Jmje8o58CHK66QrVC  ...            4.0
# 0   6DCZcSspjsKoFjzjrWoCd  ...            4.0
#
# [100 rows x 16 columns]

# %%
#Ejercicio -> Ordenar de forma ascendente o descente alguna columna del segundo archivo (20 minutos)

#Primero importamos data
data = pd.read_csv('canciones_2018.csv')
#De que vamos a extraer datos -> No modificar data original
subset = data[['name','tempo','duration_ms']]  
#Ordenar los datos por un tipo, de que forma
subset.sort_values(by='tempo',ascending=True)
# Out:
#                              name    tempo  duration_ms
# 38                        changes   64.934     121887.0
# 1                            SAD!   75.023     166606.0
# 0                      God's Plan   77.169     198973.0
# 71                  Feel It Still   79.028     163253.0
# 78                       Criminal   79.997     232550.0
# ..                            ...      ...          ...
# 98    Dusk Till Dawn - Radio Edit  180.043     239000.0
# 17                              X  180.073     173628.0
# 81                       Stir Fry  181.967     190288.0
# 93                     This Is Me  191.702     234707.0
# 85  Coraz?n (feat. Nego do Borel)  198.075     184720.0
#
# [100 rows x 3 columns]
